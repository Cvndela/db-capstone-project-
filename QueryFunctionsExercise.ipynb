# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "meta1234", db='mydb')

# %%
show_tables_query = "SHOW tables" 
cursor = connection.cursor()
cursor.execute(show_tables_query)

# %%
results=cursor.fetchall()
print(results)
# Out:
# [('Bookings',), ('Customer_Details',), ('Menu',), ('Order_Delivery_Status',), ('Orders',), ('Staff_Information',)]

# %%
cursor.execute("select GuestFullName, Guest_Contact from Orders o join Customer_Details c on o.Guest_ID=c.Guest_ID where TotalCost>60")

# %%
cursor.fetchall()
# Out:
# []
